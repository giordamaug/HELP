# %% [markdown]
# # Load optuna library

# %%
import numpy as np
import pandas as pd
import os, sys 
import optuna

# %% [markdown]
# # Load the dataset and split

# %%
from HELPpy.preprocess.loaders import load_features
from HELPpy.utility.utils import pandas_readcsv
path = '../../data'
tissue = 'Kidney'
attributes = load_features([os.path.join(path, f'{tissue}_BIO.csv'), 
                            os.path.join(path, f'{tissue}_CCcfs.csv'),
                            os.path.join(path, f'{tissue}_EmbN2V_128.csv')], 
                            fixnans=[True, True, False], normalizes=['std', 'std', None], verbose=False, show_progress=True)
labelnme = f'{tissue}_HELP.csv'
label = pandas_readcsv(os.path.join(path,labelnme), descr=f'{labelnme}', index_col=0).replace({'E': 1, 'aE':0, 'sNE': 0})
idx_common = np.intersect1d(attributes.index.values, label.index.values)
attributes = attributes.loc[idx_common]
label = label.loc[idx_common]
# Out:
# Kidney_BIO.csv:   0%|          | 0/19293 [00:00<?, ?it/s]
# Kidney_CCcfs.csv:   0%|          | 0/18608 [00:00<?, ?it/s]
# Kidney_EmbN2V_128.csv:   0%|          | 0/19314 [00:00<?, ?it/s]
# Kidney_HELP.csv:   0%|          | 0/17829 [00:00<?, ?it/s]

# %% [markdown]
# # Start tuning session

# %%
tissue = 'Kidney'
from sklearn.metrics import *
from HELPpy.models.prediction import VotingEnsembleLGBM
from optuna import Trial

from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import balanced_accuracy_score, make_scorer
from HELPpy.models.prediction import VotingEnsembleLGBM
def objective_cv(trial : Trial, X : pd.DataFrame, y : np.ndarray | pd.Series, random_state : int=42):
    params = {
        'learning_rate': trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        'n_voters': trial.suggest_int('n_voters', 1, 20, step=1),
        'n_estimators': trial.suggest_int('n_estimators', 60, 200, step=20),
        'boosting_type': trial.suggest_categorical("boosting_type", ["gbdt", "dart"])
    }
    gbm = VotingEnsembleLGBM(**params)
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)
    ba_scorer = make_scorer(balanced_accuracy_score)
    scores = cross_val_score(gbm, X, y, scoring=ba_scorer, cv=kf)
    #return np.min([np.mean(scores), np.median([scores])])
    return np.mean(scores)

savepath = '../results'
study = optuna.create_study(
    study_name=f'velgbm_{tissue}',
    direction='maximize',
    load_if_exists=True,
    storage=f'sqlite:///{savepath}/veLGBM_{tissue}_ba_cv.db'
    )
study.optimize(lambda trial: objective_cv(trial, attributes, label), n_trials=50)
best_params = study.best_params
print('Best Params:', best_params)
df = study.trials_dataframe()
df.to_csv(os.path.join(f'velgbm_{tissue}_hypersearch_ba_cv.csv'))
df.sort_values('value', ascending=False)
# Out:
# [I 2024-06-14 13:37:31,277] A new study created in RDB with name: velgbm_Kidney
# [I 2024-06-14 13:39:30,788] Trial 0 finished with value: 0.8840314356525776 and parameters: {'learning_rate': 0.031087727638145553, 'n_voters': 11, 'n_estimators': 180, 'boosting_type': 'gbdt'}. Best is trial 0 with value: 0.8840314356525776.
# [I 2024-06-14 13:40:58,163] Trial 1 finished with value: 0.8581211597990048 and parameters: {'learning_rate': 0.010380666220215586, 'n_voters': 6, 'n_estimators': 200, 'boosting_type': 'gbdt'}. Best is trial
# 39 0 days 00:01:14.457995                 dart              0.063560
# 26 0 days 00:01:52.532875                 dart              0.065108
# 47 0 days 00:01:04.836616                 gbdt              0.098334
# 42 0 days 00:00:59.234014                 gbdt              0.060848
# 25 0 days 00:01:13.891850                 gbdt              0.018323
# 11 0 days 00:01:03.068925                 gbdt              0.015863
# 8  0 days 00:01:46.010433                 dart              0.029505
# 3  0 days 00:02:36.695893                 dart              0.037974
# 7  0 days 00:00:38.444867                 dart              0.065467
# 9  0 days 00:01:54.763056                 dart              0.050532
# 28 0 days 00:01:02.107680                 gbdt              0.047467
# 36 0 days 00:01:11.444078                 dart              0.075194
# 13 0 days 00:00:45.964544                 gbdt              0.025414
# 16 0 days 00:01:08.110913                 gbdt              0.012535
# 17 0 days 00:01:34.896647                 gbdt              0.005336
# 1  0 days 00:01:27.364294                 gbdt              0.010381
# 27 0 days 00:01:52.800753                 gbdt              0.007571
# 40 0 days 00:01:12.903193                 gbdt              0.086827
# 30 0 days 00:01:23.496743                 gbdt              0.003034
# 10 0 days 00:00:56.573032                 gbdt              0.001386
# 14 0 days 00:01:40.637106                 gbdt              0.005514
# 5  0 days 00:01:04.431448                 gbdt              0.003636
# 38 0 days 00:01:16.509766                 gbdt              0.081153
# 4  0 days 00:00:58.661756                 dart              0.018938
# 12 0 days 00:01:07.115132                 gbdt              0.094523
# 45 0 days 00:01:14.865340                 dart              0.001126
#
#     params_n_estimators  params_n_voters     state
# 44                  200                8  COMPLETE
# 33                  200                8  COMPLETE
# 43                  200                8  COMPLETE
# 34                  200                7  COMPLETE
# 23                  140               13  COMPLETE
# 48                  180                9  COMPLETE
# 35                  200                7  COMPLETE
# 21                  160                9  COMPLETE
# 49                  200                8  COMPLETE
# 37                  200                7  COMPLETE
# 32                  180               11  COMPLETE
# 22                  180               12  COMPLETE
# 41                  200                7  COMPLETE
# 29                  180               10  COMPLETE
# 6                   100               12  COMPLETE
# 0                   180               11  COMPLETE
# 31                  180               10  COMPLETE
# 15                  160                9  COMPLETE
# 24                  140               15  COMPLETE
# 20                   60               10  COMPLETE
# 2                   200                6  COMPLETE
# 18                  100               16  COMPLETE
# 19                  180                9  COMPLETE
# 46                  200                6  COMPLETE
# 39                  200                7  COMPLETE
# 26                  180               13  COMPLETE
# 47                  180                5  COMPLETE
# 42                  160                5  COMPLETE
# 25                  160                8  COMPLETE
# 11                  100               11  COMPLETE
# 8                   180               12  COMPLETE
# 3                   200               17  COMPLETE
# 7                    80                6  COMPLETE
# 9                   140               18  COMPLETE
# 28                  160                4  COMPLETE
# 36                  200                5  COMPLETE
# 13                   60               14  COMPLETE
# 16                  100               14  COMPLETE
# 17                  160               12  COMPLETE
# 1                   200                6  COMPLETE
# 27                  140               19  COMPLETE
# 40                  200                3  COMPLETE
# 30                  120               16  COMPLETE
# 10                   80               14  COMPLETE
# 14                  120               20  COMPLETE
# 5                   140                8  COMPLETE
# 38                  200                2  COMPLETE
# 4                   160                4  COMPLETE
# 12                  120                1  COMPLETE
# 45                  200                8  COMPLETE

# %% [markdown]
# # Test the best model

# %%
from HELPpy.models.prediction import VotingEnsembleLGBM, k_fold_cv
clf = VotingEnsembleLGBM(**study.best_params)
# train using create_model
df_scores, scores, predictions = k_fold_cv(attributes, label, clf, n_splits=5, seed=0, show_progress=True, verbose=True)
df_scores
# Out:
# {0: 0, 1: 1}
# label
# 0        15994
# 1         1242
# Name: count, dtype: int64
# 5-fold:   0%|          | 0/5 [00:00<?, ?it/s]
#                                   measure
# ROC-AUC                     0.9574±0.0045
# Accuracy                    0.9158±0.0015
# BA                          0.8860±0.0108
# Sensitivity                 0.8511±0.0238
# Specificity                 0.9208±0.0027
# MCC                         0.5845±0.0101
# CM           [[14728, 1266], [185, 1057]]

# %%
#df = pd.read_csv(f'velgbm_{tissue}_hypersearch_mcc_ba_2.csv').sort_values(['values_1', 'values_0'], ascending=[False, False]).rename(columns={'values_0': 'BA', 'values_1': 'MCC'})
df = pd.read_csv(f'velgbm_Kidney_hypersearch_ba_cv.csv').sort_values('value', ascending=False).rename(columns={'value': 'BA'})
df.columns = df.columns.str.replace(r'params_', '')
selcolumns = ['boosting_type',	'learning_rate',	'n_estimators',	'n_voters', 'BA']
stds = df.std(numeric_only=True)
#df['BA+MCC'] = df.apply(lambda x: x.BA * stds.loc['BA'] + x.MCC * stds.loc['MCC'], axis=1)
#df['BA+MCC'] = df.apply(lambda x: x.BA  + x.MCC , axis=1)
print(df[selcolumns].sort_values('BA', ascending=False).to_latex())
# Out:
# \begin{tabular}{llrrrr}
# \toprule
#  & boosting_type & learning_rate & n_estimators & n_voters & BA \\
# \midrule
# 44 & gbdt & 0.098461 & 200 & 8 & 0.892022 \\
# 33 & gbdt & 0.081512 & 200 & 8 & 0.890714 \\
# 43 & gbdt & 0.049017 & 200 & 8 & 0.888816 \\
# 34 & gbdt & 0.079823 & 200 & 7 & 0.887190 \\
# 23 & gbdt & 0.065070 & 140 & 13 & 0.886479 \\
# 48 & gbdt & 0.045185 & 180 & 9 & 0.886413 \\
# 35 & gbdt & 0.076854 & 200 & 7 & 0.886389 \\
# 21 & gbdt & 0.050629 & 160 & 9 & 0.886107 \\
# 49 & gbdt & 0.057144 & 200 & 8 & 0.886095 \\
# 37 & gbdt & 0.077908 & 200 & 7 & 0.886046 \\
# 32 & gbdt & 0.034572 & 180 & 11 & 0.885119 \\
# 22 & gbdt & 0.039571 & 180 & 12 & 0.884895 \\
# 41 & gbdt & 0.051064 & 200 & 7 & 0.884837 \\
# 29 & gbdt & 0.030759 & 180 & 10 & 0.884531 \\
# 6 & gbdt & 0.065527 & 100 & 12 & 0.884275 \\
# 0 & gbdt & 0.031088 & 180 & 11 & 0.884031 \\
# 31 & gbdt & 0.031174 & 180 & 10 & 0.883759 \\
# 15 & gbdt & 0.041630 & 160 & 9 & 0.883406 \\
# 24 & gbdt & 0.040524 & 140 & 15 & 0.882707 \\
# 20 & gbdt & 0.099690 & 60 & 10 & 0.881841 \\
# 2 & gbdt & 0.085391 & 200 & 6 & 0.881601 \\
# 18 & gbdt & 0.056074 & 100 & 16 & 0.880590 \\
# 19 & gbdt & 0.024005 & 180 & 9 & 0.880420 \\
# 46 & gbdt & 0.073471 & 200 & 6 & 0.879457 \\
# 39 & dart & 0.063560 & 200 & 7 & 0.875153 \\
# 26 & dart & 0.065108 & 180 & 13 & 0.874942 \\
# 47 & gbdt & 0.098334 & 180 & 5 & 0.874021 \\
# 42 & gbdt & 0.060848 & 160 & 5 & 0.872442 \\
# 25 & gbdt & 0.018323 & 160 & 8 & 0.872072 \\
# 11 & gbdt & 0.015863 & 100 & 11 & 0.869731 \\
# 8 & dart & 0.029505 & 180 & 12 & 0.866041 \\
# 3 & dart & 0.037974 & 200 & 17 & 0.865953 \\
# 7 & dart & 0.065467 & 80 & 6 & 0.863830 \\
# 9 & dart & 0.050532 & 140 & 18 & 0.863715 \\
# 28 & gbdt & 0.047467 & 160 & 4 & 0.861209 \\
# 36 & dart & 0.075194 & 200 & 5 & 0.860882 \\
# 13 & gbdt & 0.025414 & 60 & 14 & 0.860572 \\
# 16 & gbdt & 0.012535 & 100 & 14 & 0.859903 \\
# 17 & gbdt & 0.005336 & 160 & 12 & 0.859829 \\
# 1 & gbdt & 0.010381 & 200 & 6 & 0.858121 \\
# 27 & gbdt & 0.007571 & 140 & 19 & 0.848071 \\
# 40 & gbdt & 0.086827 & 200 & 3 & 0.837165 \\
# 30 & gbdt & 0.003034 & 120 & 16 & 0.832801 \\
# 10 & gbdt & 0.001386 & 80 & 14 & 0.825037 \\
# 14 & gbdt & 0.005514 & 120 & 20 & 0.825036 \\
# 5 & gbdt & 0.003636 & 140 & 8 & 0.807176 \\
# 38 & gbdt & 0.081153 & 200 & 2 & 0.805407 \\
# 4 & dart & 0.018938 & 160 & 4 & 0.801913 \\
# 12 & gbdt & 0.094523 & 120 & 1 & 0.745551 \\
# 45 & dart & 0.001126 & 200 & 8 & 0.500000 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Load exisiting study from DB

# %%
import optuna
study = optuna.load_study(study_name='velgbm_Kidney', storage="sqlite:///../../results/veLGBM_Kidney_ba_cv.db")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 2
#       1 import optuna
# ----> 2 study = optuna.load_study(study_name='velgbm_Kidney', storage="sqlite:///../../results/veLGBM_Kidney_ba_cv.db")
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/_convert_positional_args.py:83, in convert_positional_args.<locals>.converter_decorator.<locals>.converter_wrapper(*args, **kwargs)
#      77     raise TypeError(
#      78         f"{func.__name__}() got multiple values for arguments {duplicated_kwds}."
#      79     )
#      81 kwargs.update(inferred_kwargs)
# ---> 83 return func(**kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/study.py:1353, in load_study(study_name, storage, sampler, pruner)
#    1347     study_name = study_names[0]
#    1348     _logger.info(
#    1349         f"Study name was omitted but trying to load '{study_name}' because that was the only "
#    1350         "study found in the storage."
#    1351     )
# -> 1353 return Study(study_name=study_name, storage=storage, sampler=sampler, pruner=pruner)
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/study.py:81, in Study.__init__(self, study_name, storage, sampler, pruner)
#      73 def __init__(
#      74     self,
#      75     study_name: str,
#    (...)
#      78     pruner: pruners.BasePruner | None = None,
#      79 ) -> None:
#      80     self.study_name = study_name
# ---> 81     storage = storages.get_storage(storage)
#      82     study_id = storage.get_study_id_from_name(study_name)
#      83     self._study_id = study_id
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/storages/__init__.py:43, in get_storage(storage)
#      39     if storage.startswith("redis"):
#      40         raise ValueError(
#      41             "RedisStorage is removed at Optuna v3.1.0. Please use JournalRedisStorage instead."
#      42         )
# ---> 43     return _CachedStorage(RDBStorage(storage))
#      44 elif isinstance(storage, RDBStorage):
#      45     return _CachedStorage(storage)
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:233, in RDBStorage.__init__(self, url, engine_kwargs, skip_compatibility_check, heartbeat_interval, grace_period, failed_trial_callback, skip_table_creation)
#     231 self._version_manager = _VersionManager(self.url, self.engine, self.scoped_session)
#     232 if not skip_compatibility_check:
# --> 233     self._version_manager.check_table_schema_compatibility()
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:1107, in _VersionManager.check_table_schema_compatibility(self)
#    1102 else:
#    1103     message += (
#    1104         "Please try updating optuna to the latest version by `$ pip install -U optuna`."
#    1105     )
# -> 1107 raise RuntimeError(message)
#
# RuntimeError: The runtime optuna version 3.6.1 is no longer compatible with the table schema (set up by optuna 3.1.1). Please execute `$ optuna storage upgrade --storage $STORAGE_URL` for upgrading the storage.

# %%
import pandas as pd
print(pd.read_csv("velgbm_Kidney_hypersearch_ba_cv.csv").replace({'':'','':'','':'','':''})sort_values('value', ascending=False).to_latex())
# Out:
# \begin{tabular}{lrrrllllrrrl}
# \toprule
#  & Unnamed: 0 & number & value & datetime_start & datetime_complete & duration & params_boosting_type & params_learning_rate & params_n_estimators & params_n_voters & state \\
# \midrule
# 37 & 37 & 37 & 0.893151 & 2024-06-05 11:48:54.638670 & 2024-06-05 11:50:51.129284 & 0 days 00:01:56.490614 & gbdt & 0.094505 & 200 & 13 & COMPLETE \\
# 15 & 15 & 15 & 0.891459 & 2024-06-05 11:16:36.759285 & 2024-06-05 11:17:48.725832 & 0 days 00:01:11.966547 & gbdt & 0.098300 & 140 & 10 & COMPLETE \\
# 44 & 44 & 44 & 0.890954 & 2024-06-05 12:01:09.467990 & 2024-06-05 12:03:01.279431 & 0 days 00:01:51.811441 & gbdt & 0.076452 & 200 & 12 & COMPLETE \\
# 43 & 43 & 43 & 0.890826 & 2024-06-05 11:59:18.529245 & 2024-06-05 12:01:09.439684 & 0 days 00:01:50.910439 & gbdt & 0.075168 & 200 & 12 & COMPLETE \\
# 41 & 41 & 41 & 0.890602 & 2024-06-05 11:55:19.637376 & 2024-06-05 11:57:14.427060 & 0 days 00:01:54.789684 & gbdt & 0.078591 & 200 & 13 & COMPLETE \\
