# %%
import pandas as pd
from HELPpy.visualization.plot import svenn_intesect
disease = "Ewing"
vucs1 = pd.read_csv(f"vucsEG_HELP_{disease}.txt", index_col=0).index.values
vucs2 = pd.read_csv(f"vucsEG_Fiper_consensus_{disease}.txt", index_col=0).index.values
vucs3 = pd.read_csv(f"vucsEG_ADAM_{disease}.txt", index_col=0).index.values
svenn_intesect([set(vucs1),set(vucs2), set(vucs3)], labels=[f'HELP_{disease}', f'FiPer_{disease}', f'AdAM_{disease}'], ylabel='EGs', figsize=(8,4))
# Out:
# (<Figure size 800x400 with 3 Axes>,
#  {'main': <AxesSubplot: xlabel='no. Genes', ylabel='EGs'>,
#   'right_side_plot': <AxesSubplot: >})
