# %%
import pandas as pd
from help.preprocess.embedding import PPI_embed
df_net = pd.read_csv('../data/Lung_PPI.csv')
df_embed = PPI_embed(df_net, method="Node2Vec", verbose=True)
# Out:
# Embedding with Node2Vec and params:
# walk_number: 10
# walk_length: 80
# p: 1.0
# q: 1.0
# dimensions: 128
# workers: 1
# window_size: 5
# epochs: 1
# learning_rate: 0.05
# min_count: 1
# seed: 42
# Creating the PPI graph: 100%|██████████| 1111550/1111550 [00:03<00:00, 337138.59it/s]
# Total number of graph nodes: 19334
# Total number of graph edges: 1108409
# Average node degree: 114.66
# There are 0 isolated genes

# %%
df_embed
# Out:
#                                                 Node2Vec_0  Node2Vec_1  \
# (clone tec14)                                     0.023051    0.014992
# 100 kDa coactivator                               0.261170   -0.524495
# 14-3-3 tau splice variant                         0.365579   -0.080783
# 3'-phosphoadenosine-5'-phosphosulfate synthase    0.178820   -0.643468
# 3-beta-hydroxysteroid dehydrogenase               0.210142    0.390334
# ...                                                    ...         ...
# pp10122                                          -0.028681    0.066035
# tRNA-uridine aminocarboxypropyltransferase        0.631674   -0.199346
# tmp_locus_54                                      0.438675    0.066111
# urf-ret                                           0.176243   -0.385673
# zf30                                              0.019257    0.029394
#
#                                                 Node2Vec_2  Node2Vec_3  \
# (clone tec14)                                    -0.141039   -0.158685
# 100 kDa coactivator                              -0.051630    0.285273
# 14-3-3 tau splice variant                         0.243886    0.021987
# 3'-phosphoadenosine-5'-phosphosulfate synthase   -0.027346   -0.015240
# 3-beta-hydroxysteroid dehydrogenase              -0.198415   -0.352966
# ...                                                    ...         ...
# pp10122                                           0.176171   -0.432947
# tRNA-uridine aminocarboxypropyltransferase       -0.048313   -0.281030
# tmp_locus_54                                     -0.017400   -0.629313
# urf-ret                                          -0.027699   -0.587800
# zf30                                             -0.055157   -0.044533
#
#                                                 Node2Vec_4  Node2Vec_5  \
# (clone tec14)                                     0.157265    0.154793
# 100 kDa coactivator                              -0.548887    0.205792
# 14-3-3 tau splice variant                        -0.737077    0.425155
# 3'-phosphoadenosine-5'-phosphosulfate synthase   -0.280513   -0.151708
# 3-beta-hydroxysteroid dehydrogenase              -0.268311   -0.065822
# ...                                                    ...         ...
# pp10122                                           0.222461    0.190343
# tRNA-uridine aminocarboxypropyltransferase       -0.186646    0.408410
# tmp_locus_54                                     -0.198265    0.144987
# urf-ret                                          -0.083288   -0.012951
# zf30                                              0.028718   -0.049564
#
#                                                 Node2Vec_6  Node2Vec_7  \
# (clone tec14)                                    -0.067947    0.118270
# 100 kDa coactivator                              -0.112976   -0.213943
# 14-3-3 tau splice variant                         0.259391   -0.252958
# 3'-phosphoadenosine-5'-phosphosulfate synthase   -0.250100   -0.428457
# 3-beta-hydroxysteroid dehydrogenase               0.061606   -0.182339
# ...                                                    ...         ...
# pp10122                                          -0.338676   -0.341797
# tRNA-uridine aminocarboxypropyltransferase       -0.364784    0.122930
# tmp_locus_54                                     -1.218005    0.147556
# urf-ret                                          -0.432041   -0.195146
# zf30                                             -0.077346    0.005204
#
#                                                 Node2Vec_8  Node2Vec_9  ...  \
# (clone tec14)                                    -0.177724    0.292236  ...
# 100 kDa coactivator                              -0.377048    0.065116  ...
# 14-3-3 tau splice variant                         0.281372    0.527371  ...
# 3'-phosphoadenosine-5'-phosphosulfate synthase   -0.844148    0.185542  ...
# 3-beta-hydroxysteroid dehydrogenase              -0.294295   -0.155456  ...
# ...                                                    ...         ...  ...
# pp10122                                           0.197020    0.137798  ...
# tRNA-uridine aminocarboxypropyltransferase       -0.137979   -0.195326  ...
# tmp_locus_54                                     -0.902313    0.258718  ...
# urf-ret                                           0.121513   -0.024590  ...
# zf30                                             -0.016760    0.031810  ...
#
#                                                 Node2Vec_118  Node2Vec_119  \
# (clone tec14)                                      -0.211920     -0.156176
# 100 kDa coactivator                                 0.150574      0.186826
# 14-3-3 tau splice variant                          -0.141555      0.131767
# 3'-phosphoadenosine-5'-phosphosulfate synthase      0.197366      0.177569
# 3-beta-hydroxysteroid dehydrogenase                -0.008944     -0.148080
# ...                                                      ...           ...
# pp10122                                            -0.202883      0.005556
# tRNA-uridine aminocarboxypropyltransferase         -0.105558     -0.139158
# tmp_locus_54                                       -0.397593      0.626247
# urf-ret                                            -0.052722      0.172050
# zf30                                               -0.036262     -0.073130
#
#                                                 Node2Vec_120  Node2Vec_121  \
# (clone tec14)                                      -0.124871     -0.182223
# 100 kDa coactivator                                -0.177846     -0.071855
# 14-3-3 tau splice variant                          -0.273269     -0.154002
# 3'-phosphoadenosine-5'-phosphosulfate synthase      0.024677      0.238864
# 3-beta-hydroxysteroid dehydrogenase                 0.073030     -0.238127
# ...                                                      ...           ...
# pp10122                                            -0.788547     -0.340978
# tRNA-uridine aminocarboxypropyltransferase          0.378296      0.150751
# tmp_locus_54                                       -1.075213      0.370802
# urf-ret                                            -0.196149      0.121417
# zf30                                                0.011830      0.014447
#
#                                                 Node2Vec_122  Node2Vec_123  \
# (clone tec14)                                       0.127756      0.011527
# 100 kDa coactivator                                 0.519840     -0.550491
# 14-3-3 tau splice variant                           0.216473     -0.345973
# 3'-phosphoadenosine-5'-phosphosulfate synthase      0.222474     -0.353596
# 3-beta-hydroxysteroid dehydrogenase                -0.019748      0.046764
# ...                                                      ...           ...
# pp10122                                             0.130789      0.051332
# tRNA-uridine aminocarboxypropyltransferase         -0.083709      0.009086
# tmp_locus_54                                       -1.487310      0.186115
# urf-ret                                            -0.023714     -0.452542
# zf30                                                0.057727     -0.020929
#
#                                                 Node2Vec_124  Node2Vec_125  \
# (clone tec14)                                       0.052182     -0.061288
# 100 kDa coactivator                                 0.041066     -0.198094
# 14-3-3 tau splice variant                           0.184679     -0.043953
# 3'-phosphoadenosine-5'-phosphosulfate synthase      0.237262     -0.401935
# 3-beta-hydroxysteroid dehydrogenase                 0.049918     -0.227539
# ...                                                      ...           ...
# pp10122                                            -0.064851      0.139500
# tRNA-uridine aminocarboxypropyltransferase          0.042860      0.004699
# tmp_locus_54                                        0.881203     -0.247443
# urf-ret                                             0.017421     -0.064719
# zf30                                                0.018321      0.014865
#
#                                                 Node2Vec_126  Node2Vec_127
# (clone tec14)                                      -0.155626      0.016534
# 100 kDa coactivator                                 0.082833      0.122187
# 14-3-3 tau splice variant                           0.128388     -0.131168
# 3'-phosphoadenosine-5'-phosphosulfate synthase     -0.266909      0.137892
# 3-beta-hydroxysteroid dehydrogenase                 0.161030     -0.244953
# ...                                                      ...           ...
# pp10122                                             0.943976     -0.461141
# tRNA-uridine aminocarboxypropyltransferase          0.214054     -0.348393
# tmp_locus_54                                       -0.532058     -0.325482
# urf-ret                                             0.212975     -0.078501
# zf30                                               -0.048886     -0.037714
#
# [19314 rows x 128 columns]

# %%
df_embed.to_csv('../data/Lung_EmbN2V_128.csv')
