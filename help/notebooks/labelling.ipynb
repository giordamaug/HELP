# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/giordamaug/HELP/blob/main/help/notebooks/labelling.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
# <a target="_blank" href="https://www.kaggle.com/notebooks/welcome?src=https://github.com/giordamaug/HELP/blob/main/help/notebooks/labelling.ipynb">
#   <img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Install HELP from GitHub
# Skip this cell if you alread have installed HELP.

# %%
# !pip install git+https://github.com/giordamaug/HELP.git
# Out:
# Collecting git+https://github.com/giordamaug/HELP.git
#   Cloning https://github.com/giordamaug/HELP.git to /tmp/pip-req-build-qbbtpyts
#   Running command git clone --filter=blob:none --quiet https://github.com/giordamaug/HELP.git /tmp/pip-req-build-qbbtpyts
#   Resolved https://github.com/giordamaug/HELP.git to commit c10f21394a1d749bd8619d23174d4a60b30a6379
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from help==1.0) (1.25.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from help==1.0) (4.66.2)
# Collecting typing (from help==1.0)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from help==1.0) (1.5.3)
# Collecting supervenn (from help==1.0)
#   Downloading supervenn-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from help==1.0) (3.7.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from help==1.0) (7.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from help==1.0) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from help==1.0) (1.11.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->help==1.0) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->help==1.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->help==1.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->help==1.0) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->help==1.0) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->help==1.0) (3.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->help==1.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->help==1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->help==1.0) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->help==1.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->help==1.0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->help==1.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->help==1.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->help==1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->help==1.0) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->help==1.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->help==1.0) (3.3.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->help==1.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->help==1.0) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->help==1.0) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->help==1.0)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.3 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->help==1.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->help==1.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->help==1.0) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->help==1.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->help==1.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->help==1.0) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->help==1.0) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->help==1.0) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->help==1.0) (0.8.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (3.1.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (5.7.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.18.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->help==1.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->help==1.0) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (4.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (2.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (4.19.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->help==1.0) (2.21)
# Building wheels for collected packages: help, typing
#   Building wheel for help (setup.py) ... done
#   Created wheel for help: filename=help-1.0-py3-none-any.whl size=35901 sha256=de3e55c681a51898b5e456150028a7af2a92aa02f26dd0e8e58020c07bb8e4a5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wo0mvv4_/wheels/2b/c2/d4/1e25efd10be848dfb30253a32bf049902129bae3b25aa84873
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26304 sha256=fad5465a20db9ba908217ef67afb6146ce03073bcc2492903ee5dd144d8f2785
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
# Successfully built help typing
# Installing collected packages: typing, jedi, supervenn, help
# Successfully installed help-1.0 jedi-0.19.1 supervenn-0.4.2 typing-3.7.4.3

# %% [markdown]
# # Download the input files
# In this cell we download from GitHub repository the label file and the attribute files. Skip this step if you already have these input files locally.

# %%
# !wget https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_HELP.csv
# !wget https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_BIO.csv
for i in range(5):
  # !wget https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_CCcfs_{i}.csv
# !wget https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_EmbN2V_128.csv
# Out:
# --2024-03-07 21:00:20--  https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_HELP.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 180249 (176K) [text/plain]
# Saving to: ‘Kidney_HELP.csv’
#
# Kidney_HELP.csv     100%[===================>] 176.02K  --.-KB/s    in 0.006s
#
# 2024-03-07 21:00:20 (29.3 MB/s) - ‘Kidney_HELP.csv’ saved [180249/180249]
#
# --2024-03-07 21:00:20--  https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_BIO.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2098574 (2.0M) [text/plain]
# Saving to: ‘Kidney_BIO.csv’
#
# Kidney_BIO.csv      100%[===================>]   2.00M  --.-KB/s    in 0.01s
#
# 2024-03-07 21:00:20 (151 MB/s) - ‘Kidney_BIO.csv’ saved [2098574/2098574]
#
# --2024-03-07 21:00:21--  https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_CCcfs_0.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47616626 (45M) [text/plain]
# Saving to: ‘Kidney_CCcfs_0.csv’
#
# Kidney_CCcfs_0.csv  100%[===================>]  45.41M   261MB/s    in 0.2s
#
# 2024-03-07 21:00:21 (261 MB/s) - ‘Kidney_CCcfs_0.csv’ saved [47616626/47616626]
#
# --2024-03-07 21:00:21--  https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_CCcfs_1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47687578 (45M) [text/plain]
# Saving to: ‘Kidney_CCcfs_1.csv’
#
# Kidney_CCcfs_1.csv  100%[===================>]  45.48M  --.-KB/s    in 0.1s
#
# 2024-03-07 21:00:22 (306 MB/s) - ‘Kidney_CCcfs_1.csv’ saved [47687578/47687578]
#
# --2024-03-07 21:00:22--  https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_CCcfs_2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49159349 (47M) [text/plain]
# Saving to: ‘Kidney_CCcfs_2.csv’
#
# Kidney_CCcfs_2.csv  100%[===================>]  46.88M   242MB/s    in 0.2s
#
# 2024-03-07 21:00:22 (242 MB/s) - ‘Kidney_CCcfs_2.csv’ saved [49159349/49159349]
#
# --2024-03-07 21:00:22--  https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_CCcfs_3.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48980264 (47M) [text/plain]
# Saving to: ‘Kidney_CCcfs_3.csv’
#
# Kidney_CCcfs_3.csv  100%[===================>]  46.71M   197MB/s    in 0.2s
#
# 2024-03-07 21:00:23 (197 MB/s) - ‘Kidney_CCcfs_3.csv’ saved [48980264/48980264]
#
# --2024-03-07 21:00:23--  https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_CCcfs_4.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49363273 (47M) [text/plain]
# Saving to: ‘Kidney_CCcfs_4.csv’
#
# Kidney_CCcfs_4.csv  100%[===================>]  47.08M  --.-KB/s    in 0.1s
#
# 2024-03-07 21:00:24 (322 MB/s) - ‘Kidney_CCcfs_4.csv’ saved [49363273/49363273]
#
# --2024-03-07 21:00:24--  https://raw.githubusercontent.com/giordamaug/HELP/main/help/datafinal/Kidney_EmbN2V_128.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27762176 (26M) [text/plain]
# Saving to: ‘Kidney_EmbN2V_128.csv’
#
# Kidney_EmbN2V_128.c 100%[===================>]  26.48M  --.-KB/s    in 0.08s
#
# 2024-03-07 21:00:24 (316 MB/s) - ‘Kidney_EmbN2V_128.csv’ saved [27762176/27762176]

# %% [markdown]
# # Set data path

# %%
datapath = "../data"

# %% [markdown]
# # Load the CRISPR data file

# %%
import pandas as pd
import os
df = pd.read_csv(os.path.join(datapath, "CRISPRGeneEffect.csv")).rename(columns={'Unnamed: 0': 'gene'}).rename(columns=lambda x: x.split(' ')[0]).set_index('gene').T
print(f'{df.isna().sum().sum()} NaN over {len(df)*len(df.columns)} values')
df
# Out:
# 739493 NaN over 20287300 values
# gene     ACH-000001  ACH-000004  ACH-000005  ACH-000007  ACH-000009  \
# A1BG      -0.122637    0.019756   -0.107208   -0.031027    0.008888
# A1CF       0.025881   -0.083640   -0.023211   -0.137850   -0.146566
# A2M        0.034217   -0.060118    0.200204    0.067704    0.084471
# A2ML1     -0.128082   -0.027417    0.116039    0.107988    0.089419
# A3GALT2   -0.031285   -0.036116   -0.172227    0.007992    0.065109
# ...             ...         ...         ...         ...         ...
# ZYG11A    -0.289724    0.032983   -0.201273   -0.100344   -0.112703
# ZYG11B    -0.062972   -0.410392   -0.178877   -0.462160   -0.598698
# ZYX        0.074180    0.113156   -0.055349   -0.001555    0.095877
# ZZEF1      0.111244    0.234388   -0.002161   -0.325964   -0.026742
# ZZZ3      -0.467908   -0.088306   -0.186842   -0.486660   -0.320759
#
# gene     ACH-000011  ACH-000012  ACH-000013  ACH-000015  ACH-000017  ...  \
# A1BG       0.022670   -0.096631    0.049811   -0.099040   -0.044896  ...
# A1CF      -0.057743   -0.024440   -0.158811   -0.070409   -0.115830  ...
# A2M        0.079679    0.041922   -0.003968   -0.029389    0.024537  ...
# A2ML1      0.227512    0.039121    0.034778    0.084594   -0.003710  ...
# A3GALT2   -0.130448    0.028947   -0.120875   -0.052288   -0.336776  ...
# ...             ...         ...         ...         ...         ...  ...
# ZYG11A     0.013401    0.005124   -0.089180   -0.005409   -0.070396  ...
# ZYG11B    -0.296421   -0.131949   -0.145737   -0.216393   -0.257916  ...
# ZYX        0.067705   -0.109147   -0.034886   -0.137350    0.029457  ...
# ZZEF1     -0.232453   -0.164482   -0.175850   -0.168087   -0.284838  ...
# ZZZ3      -0.347234   -0.277397   -0.519586   -0.282338   -0.247634  ...
#
# gene     ACH-002693  ACH-002710  ACH-002785  ACH-002799  ACH-002800  \
# A1BG      -0.072582   -0.033722   -0.053881   -0.060617    0.025795
# A1CF      -0.237311   -0.108704   -0.114864   -0.042591   -0.132627
# A2M       -0.065940    0.079277    0.069333    0.030989    0.249826
# A2ML1      0.101541    0.038977    0.066599    0.043809    0.064657
# A3GALT2    0.005374   -0.144070   -0.256227   -0.116473   -0.294305
# ...             ...         ...         ...         ...         ...
# ZYG11A    -0.296880   -0.084936   -0.128569   -0.110504   -0.087171
# ZYG11B    -0.332415   -0.193408   -0.327408   -0.257879   -0.349111
# ZYX       -0.005090   -0.218960   -0.053033   -0.041612   -0.057478
# ZZEF1     -0.188751   -0.120449   -0.267081    0.006148   -0.189602
# ZZZ3      -0.239991   -0.311396   -0.202158   -0.195154   -0.107107
#
# gene     ACH-002834  ACH-002847  ACH-002922  ACH-002925  ACH-002926
# A1BG      -0.055721   -0.009973   -0.025991   -0.127639   -0.068666
# A1CF      -0.121228   -0.119813   -0.007706   -0.040705   -0.107530
# A2M        0.072790    0.044097   -0.038468    0.134556    0.067806
# A2ML1      0.021916    0.041358    0.236576   -0.047984    0.112071
# A3GALT2   -0.221940   -0.146565   -0.239690   -0.116114   -0.149897
# ...             ...         ...         ...         ...         ...
# ZYG11A     0.024959   -0.119911   -0.079342   -0.043555   -0.045115
# ZYG11B     0.015259   -0.289412   -0.347484   -0.335270   -0.307900
# ZYX       -0.306562   -0.195097   -0.085302   -0.208063    0.070671
# ZZEF1     -0.148368   -0.206400   -0.095965   -0.094741   -0.187813
# ZZZ3      -0.579576   -0.486525   -0.346272   -0.222404   -0.452143
#
# [18443 rows x 1100 columns]

# %% [markdown]
# # Load the map between cell lines and tissues

# %%
df_map = pd.read_csv(os.path.join(datapath, "Model.csv"))
print(df_map[['OncotreeLineage']].value_counts())
df_map
# Out:
# OncotreeLineage
# Lung                         249
# Lymphoid                     211
# CNS/Brain                    122
# Skin                         120
# Esophagus/Stomach             95
# Breast                        94
# Bowel                         89
# Head and Neck                 84
# Bone                          77
# Myeloid                       77
# Ovary/Fallopian Tube          75
# Kidney                        73
# Pancreas                      66
# Peripheral Nervous System     56
# Soft Tissue                   55
# Biliary Tract                 44
# Uterus                        41
# Fibroblast                    41
# Bladder/Urinary Tract         39
# Normal                        39
# Pleura                        35
# Liver                         29
# Cervix                        25
# Eye                           21
# Thyroid                       18
# Prostate                      15
# Testis                         7
# Vulva/Vagina                   5
# Muscle                         5
# Ampulla of Vater               4
# Hair                           2
# Other                          1
# Embryonal                      1
# Adrenal Gland                  1
# Name: count, dtype: int64
#          ModelID  PatientID CellLineName StrippedCellLineName DepmapModelType  \
# 0     ACH-000001  PT-gj46wT  NIH:OVCAR-3            NIHOVCAR3           HGSOC
# 1     ACH-000002  PT-5qa3uk        HL-60                 HL60             AML
# 2     ACH-000003  PT-puKIyc        CACO2                CACO2            COAD
# 3     ACH-000004  PT-q4K2cp          HEL                  HEL             AML
# 4     ACH-000005  PT-q4K2cp   HEL 92.1.7              HEL9217             AML
# ...          ...        ...          ...                  ...             ...
# 1916  ACH-003157  PT-QDEP9D    ABM-T0822             ABMT0822        ZIMMMPLC
# 1917  ACH-003158  PT-nszsxG    ABM-T9220             ABMT9220        ZIMMSMCI
# 1918  ACH-003159  PT-AUxVvV    ABM-T9233             ABMT9233        ZIMMRSCH
# 1919  ACH-003160  PT-AUxVvV    ABM-T9249             ABMT9249        ZIMMGMCH
# 1920  ACH-003161  PT-or1hkT    ABM-T9430             ABMT9430         ZIMMPSC
#
#            OncotreeLineage     OncotreePrimaryDisease  \
# 0     Ovary/Fallopian Tube   Ovarian Epithelial Tumor
# 1                  Myeloid     Acute Myeloid Leukemia
# 2                    Bowel  Colorectal Adenocarcinoma
# 3                  Myeloid     Acute Myeloid Leukemia
# 4                  Myeloid     Acute Myeloid Leukemia
# ...                    ...                        ...
# 1916                  Lung              Non-Cancerous
# 1917                Muscle              Non-Cancerous
# 1918                  Hair              Non-Cancerous
# 1919                  Hair              Non-Cancerous
# 1920              Pancreas              Non-Cancerous
#
#                                         OncotreeSubtype OncotreeCode  \
# 0                      High-Grade Serous Ovarian Cancer        HGSOC
# 1                                Acute Myeloid Leukemia          AML
# 2                                  Colon Adenocarcinoma         COAD
# 3                                Acute Myeloid Leukemia          AML
# 4                                Acute Myeloid Leukemia          AML
# ...                                                 ...          ...
# 1916                            Immortalized MPLC Cells          NaN
# 1917       Immortalized Smooth Muscle Cells, Intestinal          NaN
# 1918  Immortalized Hair Follicle Inner Root Sheath C...          NaN
# 1919            Immortalized Hair Germinal Matrix Cells          NaN
# 1920              Immortalized Pancreatic Stromal Cells          NaN
#
#      LegacyMolecularSubtype  ...  TissueOrigin  \
# 0                       NaN  ...           NaN
# 1                       NaN  ...           NaN
# 2                       NaN  ...           NaN
# 3                       NaN  ...           NaN
# 4                       NaN  ...           NaN
# ...                     ...  ...           ...
# 1916                    NaN  ...           NaN
# 1917                    NaN  ...           NaN
# 1918                    NaN  ...           NaN
# 1919                    NaN  ...           NaN
# 1920                    NaN  ...           NaN
#
#                                         CCLEName  CatalogNumber PlateCoating  \
# 0                                NIHOVCAR3_OVARY         HTB-71          NaN
# 1        HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        CCL-240          NaN
# 2                          CACO2_LARGE_INTESTINE         HTB-37          NaN
# 3         HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         ACC 11          NaN
# 4     HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        HEL9217          NaN
# ...                                          ...            ...          ...
# 1916                                         NaN            NaN          NaN
# 1917                                         NaN            NaN          NaN
# 1918                                         NaN            NaN          NaN
# 1919                                         NaN            NaN          NaN
# 1920                                         NaN            NaN          NaN
#
#      ModelDerivationMaterial PublicComments WTSIMasterCellID SangerModelID  \
# 0                        NaN            NaN           2201.0     SIDM00105
# 1                        NaN            NaN             55.0     SIDM00829
# 2                        NaN            NaN              NaN     SIDM00891
# 3                        NaN            NaN            783.0     SIDM00594
# 4                        NaN            NaN              NaN     SIDM00593
# ...                      ...            ...              ...           ...
# 1916                     NaN            NaN              NaN           NaN
# 1917                     NaN            NaN              NaN           NaN
# 1918                     NaN            NaN              NaN           NaN
# 1919                     NaN            NaN              NaN           NaN
# 1920                     NaN            NaN              NaN           NaN
#
#       COSMICID   LegacySubSubtype
# 0     905933.0  high_grade_serous
# 1     905938.0                 M3
# 2          NaN                NaN
# 3     907053.0                 M6
# 4          NaN                 M6
# ...        ...                ...
# 1916       NaN                NaN
# 1917       NaN                NaN
# 1918       NaN                NaN
# 1919       NaN                NaN
# 1920       NaN                NaN
#
# [1921 rows x 36 columns]

# %%
from help.utility.selection import filter_crispr_by_model
df = filter_crispr_by_model(df, df_map, minlines=10, line_group='OncotreeLineage')
df
# Out:
# gene     ACH-000001  ACH-000004  ACH-000005  ACH-000007  ACH-000009  \
# A1BG      -0.122637    0.019756   -0.107208   -0.031027    0.008888
# A1CF       0.025881   -0.083640   -0.023211   -0.137850   -0.146566
# A2M        0.034217   -0.060118    0.200204    0.067704    0.084471
# A2ML1     -0.128082   -0.027417    0.116039    0.107988    0.089419
# A3GALT2   -0.031285   -0.036116   -0.172227    0.007992    0.065109
# ...             ...         ...         ...         ...         ...
# ZYG11A    -0.289724    0.032983   -0.201273   -0.100344   -0.112703
# ZYG11B    -0.062972   -0.410392   -0.178877   -0.462160   -0.598698
# ZYX        0.074180    0.113156   -0.055349   -0.001555    0.095877
# ZZEF1      0.111244    0.234388   -0.002161   -0.325964   -0.026742
# ZZZ3      -0.467908   -0.088306   -0.186842   -0.486660   -0.320759
#
# gene     ACH-000011  ACH-000012  ACH-000013  ACH-000015  ACH-000017  ...  \
# A1BG       0.022670   -0.096631    0.049811   -0.099040   -0.044896  ...
# A1CF      -0.057743   -0.024440   -0.158811   -0.070409   -0.115830  ...
# A2M        0.079679    0.041922   -0.003968   -0.029389    0.024537  ...
# A2ML1      0.227512    0.039121    0.034778    0.084594   -0.003710  ...
# A3GALT2   -0.130448    0.028947   -0.120875   -0.052288   -0.336776  ...
# ...             ...         ...         ...         ...         ...  ...
# ZYG11A     0.013401    0.005124   -0.089180   -0.005409   -0.070396  ...
# ZYG11B    -0.296421   -0.131949   -0.145737   -0.216393   -0.257916  ...
# ZYX        0.067705   -0.109147   -0.034886   -0.137350    0.029457  ...
# ZZEF1     -0.232453   -0.164482   -0.175850   -0.168087   -0.284838  ...
# ZZZ3      -0.347234   -0.277397   -0.519586   -0.282338   -0.247634  ...
#
# gene     ACH-002693  ACH-002710  ACH-002785  ACH-002799  ACH-002800  \
# A1BG      -0.072582   -0.033722   -0.053881   -0.060617    0.025795
# A1CF      -0.237311   -0.108704   -0.114864   -0.042591   -0.132627
# A2M       -0.065940    0.079277    0.069333    0.030989    0.249826
# A2ML1      0.101541    0.038977    0.066599    0.043809    0.064657
# A3GALT2    0.005374   -0.144070   -0.256227   -0.116473   -0.294305
# ...             ...         ...         ...         ...         ...
# ZYG11A    -0.296880   -0.084936   -0.128569   -0.110504   -0.087171
# ZYG11B    -0.332415   -0.193408   -0.327408   -0.257879   -0.349111
# ZYX       -0.005090   -0.218960   -0.053033   -0.041612   -0.057478
# ZZEF1     -0.188751   -0.120449   -0.267081    0.006148   -0.189602
# ZZZ3      -0.239991   -0.311396   -0.202158   -0.195154   -0.107107
#
# gene     ACH-002834  ACH-002847  ACH-002922  ACH-002925  ACH-002926
# A1BG      -0.055721   -0.009973   -0.025991   -0.127639   -0.068666
# A1CF      -0.121228   -0.119813   -0.007706   -0.040705   -0.107530
# A2M        0.072790    0.044097   -0.038468    0.134556    0.067806
# A2ML1      0.021916    0.041358    0.236576   -0.047984    0.112071
# A3GALT2   -0.221940   -0.146565   -0.239690   -0.116114   -0.149897
# ...             ...         ...         ...         ...         ...
# ZYG11A     0.024959   -0.119911   -0.079342   -0.043555   -0.045115
# ZYG11B     0.015259   -0.289412   -0.347484   -0.335270   -0.307900
# ZYX       -0.306562   -0.195097   -0.085302   -0.208063    0.070671
# ZZEF1     -0.148368   -0.206400   -0.095965   -0.094741   -0.187813
# ZZZ3      -0.579576   -0.486525   -0.346272   -0.222404   -0.452143
#
# [18443 rows x 1091 columns]

# %% [markdown]
# # Select some tissues
# In this section we select only cell-lines of a specific tissue. We check that, once CRISPR datafile is reduced to a subset of total cell-lines, that there is no row (gene) in the datafile with all NaN as cell values. Inthat case we remove those rows (genes) before applying the labelling algorithm.
#
# We start labelling genes for the `Kidney` tissue...

# %%
tissue = 'Kidney'
from help.utility.selection import select_cell_lines, delrows_with_nan_percentage
from help.models.labelling import labelling
cell_lines = select_cell_lines(df, df_map, [tissue])
print(f"Selecting {len(cell_lines)} cell-lines")
# remove rows with all nans
df_nonan = delrows_with_nan_percentage(df[cell_lines], perc=95)
df_label1 = labelling(df_nonan, columns = cell_lines, n_classes=2, labelnames={0: 'E', 1: 'aE', 2: 'sNE'}, mode='two-by-two', algorithm='otsu', reducefoo=max)
#df_label1.to_csv(os.path.join(datapath, f"label_{tissue}_Yen.csv"))
df_label1.value_counts(normalize=False), f"Nan: {df_label['label'].isna().sum()}"
# Out:
# Selecting 37 cell-lines
# Removed 512 rows from 18443 with at least 95% NaN
#   0%|          | 0/37 [00:00<?, ?it/s]
# 100%|██████████| 37/37 [00:00<00:00, 584.93it/s]
# 100%|██████████| 37/37 [00:00<00:00, 745.94it/s]
# (label
#  sNE      13457
#  aE        3221
#  E         1253
#  Name: count, dtype: int64,
#  'Nan: 0')

# %% [markdown]
# ... then we do it for the `Lung` tissue ...

# %%
tissue = 'Lung'
from help.utility.selection import select_cell_lines, delrows_with_nan_percentage
from help.models.labelling import labelling
cell_lines = select_cell_lines(df, df_map, [tissue])
print(f"Selecting {len(cell_lines)} cell-lines")
# remove rows with all nans
df_nonan = delrows_with_nan_percentage(df[cell_lines], perc=95)
#df_label = labelling(df_nonan, columns = cell_lines, n_classes=2, mode='flat-multi', algorithm='otsu')
df_label2 = labelling(df_nonan, columns = [cell_lines], n_classes=2, labelnames={2: 'sNE', 1: 'aE', 0:'E'}, mode='two-by-two', algorithm='otsu')
#df_label2.to_csv(os.path.join(datapath, f"{tissue}_HELP.csv"))
df_label2.value_counts(), f"Nan: {df_label2['label'].isna().sum()}"
# Out:
# Selecting 119 cell-lines
# Removed 512 rows from 18443 with at least 95% NaN
# 100%|██████████| 119/119 [00:00<00:00, 694.89it/s]
# 100%|██████████| 119/119 [00:00<00:00, 753.15it/s]
# (label
#  sNE      13832
#  aE        2863
#  E         1236
#  Name: count, dtype: int64,
#  'Nan: 0')

# %% [markdown]
# # Working on diseases ...
# In the same way we can make gene essentiality labelling based on disease related information, by allowing the labelling algorith to focus on CRISPR cell-lines related so spcific disease. In order to work on disease-cells association, we use the same selection functions as before but using a different Model column as selector (`OncotreePrimaryDisease`).

# %%
disease = 'Acute Myeloid Leukemia'
from help.utility.selection import select_cell_lines, delrows_with_nan_percentage
from help.models.labelling import labelling
cell_lines = select_cell_lines(df, df_map, [disease], line_group='OncotreePrimaryDisease')  # change default from 'OncotreeLineage'
print(f"Selecting {len(cell_lines)} cell-lines")
# remove rows with all nans
df_nonan = delrows_with_nan_percentage(df[cell_lines], perc=100)
df_label = labelling(df_nonan, columns = cell_lines, n_classes=2, mode='flat-multi', algorithm='otsu')
#df_label.to_csv(os.path.join(datapath, f"label_{disease}.csv"))
df_label.value_counts(), f"Nan: {df_label['label'].isna().sum()}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-44cbb68e2d92> in <module>
#       2 from help.utility.selection import select_cell_lines, delrows_with_nan_percentage
#       3 from help.models.labelling import labelling
# ----> 4 cell_lines = select_cell_lines(df, df_map, [disease], line_group='OncotreePrimaryDisease')  # change default from 'OncotreeLineage'
#       5 print(f"Selecting {len(cell_lines)} cell-lines")
#       6 # remove rows with all nans
#
# NameError: name 'df' is not defined
